# %%
import requests
import getpass
import socket
import json
import zipfile
import io
import math
import os
import shutil
import pprint
import time
import geopandas as gpd
import matplotlib.pyplot as plt
import fiona
import h5py
import re
# To read KML files with geopandas, we will need to enable KML support in fiona (disabled by default)
fiona.drvsupport.supported_drivers['LIBKML'] = 'rw'
from shapely.geometry import Polygon, mapping
from shapely.geometry.polygon import orient
from statistics import mean
from requests.auth import HTTPBasicAuth

# %%
# Earthdata Login credentials

# Enter your Earthdata Login user name
uid = 'eric_keenan'
# Enter your email address associated with your Earthdata Login account
email = 'eric.keenan@colorado.edu'
pswd = getpass.getpass('Earthdata Login:')
# Out:
# Earthdata Login: ············

# %%
# Request token from Common Metadata Repository using Earthdata credentials
token_api_url = 'https://cmr.earthdata.nasa.gov/legacy-services/rest/tokens'
hostname = socket.gethostname()
ip = socket.gethostbyname(hostname)

data = {
    'token': {
        'username': uid,
        'password': pswd,
        'client_id': 'NSIDC_client_id',
        'user_ip_address': ip
    }
}
headers={'Accept': 'application/json'}
response = requests.post(token_api_url, json=data, headers=headers)
token = json.loads(response.content)['token']['id']
print(token)
#4351E4A7-9907-AEA1-82B3-FE2A36C88659
# Out:
# 7FFDD4DD-3C08-A489-E8F8-8D7D26F3096C

# %%
# Input data set ID (e.g. ATL06) of interest here, also known as "short name".

short_name = 'ATL06'

# %%
# Get json response from CMR collection metadata and print results. This provides high-level metadata on a data set or "collection", provide in json format.

params = {
    'short_name': short_name
}

cmr_collections_url = 'https://cmr.earthdata.nasa.gov/search/collections.json'
response = requests.get(cmr_collections_url, params=params)
results = json.loads(response.content)
pprint.pprint(results)
# Out:
# {'feed': {'entry': [{'archive_center': 'NASA NSIDC DAAC',
#                      'associations': {'services': ['S1568899363-NSIDC_ECS',
#                                                    'S1613689509-NSIDC_ECS',
#                                                    'S1613669681-NSIDC_ECS']},
#                      'boxes': ['-90 -180 90 180'],
#                      'browse_flag': False,
#                      'coordinate_system': 'CARTESIAN',
#                      'data_center': 'NSIDC_ECS',
#                      'dataset_id': 'ATLAS/ICESat-2 L3A Land Ice Height V001',
#                      'has_formats': True,
#                      'has_spatial_subsetting': True,
#                      'has_temporal_subsetting': True,
#                      'has_transforms': False,
#                      'has_variables': True,
#                      'id': 'C1511847675-NSIDC_ECS',
#                      'links': [{'href': 'https://n5eil01u.ecs.nsidc.org/ATLAS/ATL06.001/',
#                                 'hreflang': 'en-US',
#                                 'length': '0.0KB',
#                                 'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                {'href': 'http://nsidc.org/daac/subscriptions.html',
#                                 'hreflang': 'en-US',
#                                 'length': '0.0KB',
#                                 'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                {'href': 'https://search.earthdata.nasa.gov/search/granules?p=C1511847675-NSIDC_ECS&m=-87.87967837686685!9.890967019347585!1!1!0!0%2C2&tl=1542476530!4!!&q=atl06&ok=atl06',
#                                 'hreflang': 'en-US',
#                                 'length': '0.0KB',
#                                 'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                {'href': 'https://openaltimetry.org/',
#                                 'hreflang': 'en-US',
#                                 'length': '0.0KB',
#                                 'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#'},
#                                {'href': 'https://doi.org/10.5067/ATLAS/ATL06.001',
#                                 'hreflang': 'en-US',
#                                 'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#'},
#                                {'href': 'https://doi.org/10.5067/ATLAS/ATL06.001',
#                                 'hreflang': 'en-US',
#                                 'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#'}],
#                      'online_access_flag': True,
#                      'orbit_parameters': {'inclination_angle': '92.0',
#                                           'number_of_orbits': '0.071428571',
#                                           'period': '94.29',
#                                           'start_circular_latitude': '0.0',
#                                           'swath_width': '36.0'},
#                      'organizations': ['NASA NSIDC DAAC',
#                                        'NASA/GSFC/EOS/ESDIS'],
#                      'original_format': 'ISO19115',
#                      'processing_level_id': 'Level 3',
#                      'short_name': 'ATL06',
#                      'summary': 'This data set (ATL06) provides geolocated, '
#                                 'land-ice surface heights (above the WGS 84 '
#                                 'ellipsoid, ITRF2014 reference frame), plus '
#                                 'ancillary parameters that can be used to '
#                                 'interpret and assess the quality of the '
#                                 'height estimates. The data were acquired by '
#                                 'the Advanced Topographic Laser Altimeter '
#                                 'System (ATLAS) instrument on board the Ice, '
#                                 'Cloud and land Elevation Satellite-2 '
#                                 '(ICESat-2) observatory.',
#                      'time_start': '2018-10-14T00:00:00.000Z',
#                      'title': 'ATLAS/ICESat-2 L3A Land Ice Height V001',
#                      'version_id': '001'}],
#           'id': 'https://cmr.earthdata.nasa.gov:443/search/collections.json?short_name=ATL06',
#           'title': 'ECHO dataset metadata',
#           'updated': '2019-06-18T22:44:52.932Z'}}

# %%
# Find all instances of 'version_id' in metadata and print most recent version number

versions = [i['version_id'] for i in results['feed']['entry']]
latest_version = max(versions)
print(latest_version)
# Out:
# 001

# %%
# Input temporal range 

# Input start date in yyyy-MM-dd format
start_date = '2018-10-15'
# Input start time in HH:mm:ss format
start_time = '00:00:00'
# Input end date in yyyy-MM-dd format
end_date = '2018-10-31'
# Input end time in HH:mm:ss format
end_time = '23:59:59'

temporal = start_date + 'T' + start_time + 'Z' + ',' + end_date + 'T' + end_time + 'Z'
print(temporal)
# Out:
# 2018-10-15T00:00:00Z,2018-10-31T23:59:59Z

# %%
# # Commenting for tutorial since we will be walking through option 3 (spatial file input) together
# # Bounding Box spatial parameter in 'W,S,E,N' format

# Input bounding box
# Input lower left longitude in decimal degrees
LL_lon = '9'
# Input lower left latitude in decimal degrees
LL_lat = '-72'
# Input upper right longitude in decimal degrees
UR_lon = '15'
# Input upper right latitude in decimal degrees
UR_lat = '-70'

bounding_box = LL_lon + ',' + LL_lat + ',' + UR_lon + ',' + UR_lat
# aoi value used for CMR params below
aoi = '1'
print(bounding_box)
# Out:
# 9,-72,15,-70

# %%
#Create CMR parameters used for granule search. Modify params depending on bounding_box or polygon input.

if aoi == '1':
# bounding box input:
    params = {
    'short_name': short_name,
    'version': latest_version,
    'temporal': temporal,
    'page_size': 100,
    'page_num': 1,
    'bounding_box': bounding_box
    }
else:
    
# If polygon input (either via coordinate pairs or shapefile/KML/KMZ):
    params = {
    'short_name': short_name,
    'version': latest_version,
    'temporal': temporal,
    'page_size': 100,
    'page_num': 1,
    'polygon': polygon,
    }

print('CMR search parameters: ', params)
# Out:
# CMR search parameters:  {'short_name': 'ATL06', 'version': '001', 'temporal': '2018-10-15T00:00:00Z,2018-10-31T23:59:59Z', 'page_size': 100, 'page_num': 1, 'bounding_box': '9,-72,15,-70'}

# %%
# Query number of granules using our (paging over results)

granule_search_url = 'https://cmr.earthdata.nasa.gov/search/granules'

granules = []
while True:
    response = requests.get(granule_search_url, params=params, headers=headers)
    results = json.loads(response.content)

    if len(results['feed']['entry']) == 0:
        # Out of results, so break out of loop
        break

    # Collect results and increment page_num
    granules.extend(results['feed']['entry'])
    params['page_num'] += 1

    
# Get number of granules over my area and time of interest
len(granules)
# Out:
# 8

# %%
granule_sizes = [float(granule['granule_size']) for granule in granules]

# Average size of granules in MB
mean(granule_sizes)
# Out:
# 37.0019710064

# %%
# Total volume in MB
sum(granule_sizes)
# Out:
# 296.0157680512

# %%
# Query service capability URL 

from xml.etree import ElementTree as ET

capability_url = f'https://n5eil02u.ecs.nsidc.org/egi/capabilities/{short_name}.{latest_version}.xml'

print(capability_url)
# Out:
# https://n5eil02u.ecs.nsidc.org/egi/capabilities/ATL06.001.xml

# %%
# Create session to store cookie and pass credentials to capabilities url

session = requests.session()
s = session.get(capability_url)
response = session.get(s.url,auth=(uid,pswd))

root = ET.fromstring(response.content)

# %%
granules
# Out:
# [{'producer_granule_id': 'ATL06_20181015021234_02510110_001_01.h5',
#   'time_start': '2018-10-15T02:12:34.000Z',
#   'orbit': {'ascending_crossing': '-144.95783291940415',
#    'start_lat': '-50',
#    'start_direction': 'D',
#    'end_lat': '-79',
#    'end_direction': 'D'},
#   'updated': '2019-05-24T10:38:32.954Z',
#   'orbit_calculated_spatial_domains': [{'equator_crossing_date_time': '2018-10-15T01:12:24.840Z',
#     'equator_crossing_longitude': '-144.95783291940415',
#     'orbit_number': '452'}],
#   'dataset_id': 'ATLAS/ICESat-2 L3A Land Ice Height V001',
#   'data_center': 'NSIDC_ECS',
#   'title': 'SC:ATL06.001:161156555',
#   'coordinate_system': 'ORBIT',
#   'time_end': '2018-10-15T02:20:15.000Z',
#   'id': 'G1614833904-NSIDC_ECS',
#   'original_format': 'ISO-SMAP',
#   'granule_size': '54.1784553528',
#   'browse_flag': True,
#   'polygons': [['-49.68413386180368 17.892561183685707 -68.7320269604 14.051725481409457 -78.90103528304857 8.68024824992665 -78.84246074971497 7.029474170741279 -68.70088168755736 13.163423199880844 -49.66666372665919 17.392703939632188 -49.68413386180368 17.892561183685707']],
#   'collection_concept_id': 'C1511847675-NSIDC_ECS',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'type': 'application/x-hdfeos',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2018.10.15/ATL06_20181015021234_02510110_001_01.h5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.default.default1.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.default.default2.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt1l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt1l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt1l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt1l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt1l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt1r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt1r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt1r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt1r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt1r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt2l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt2l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt2l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt2l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt2l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt2r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt2r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt2r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt2r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt2r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt3l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt3l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt3l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt3l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt3l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt3r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt3r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt3r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt3r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181015021234_02510110_001_01_BRW.gt3r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'type': 'text/xml',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2018.10.15/ATL06_20181015021234_02510110_001_01.iso.xml'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/ATLAS/ATL06.001/'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'http://nsidc.org/daac/subscriptions.html'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C1511847675-NSIDC_ECS&m=-87.87967837686685!9.890967019347585!1!1!0!0%2C2&tl=1542476530!4!!&q=atl06&ok=atl06'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://openaltimetry.org/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'}]},
#  {'producer_granule_id': 'ATL06_20181015150017_02590112_001_01.h5',
#   'time_start': '2018-10-15T15:00:17.000Z',
#   'orbit': {'ascending_crossing': '26.084411156968176',
#    'start_lat': '-79',
#    'start_direction': 'A',
#    'end_lat': '-50',
#    'end_direction': 'A'},
#   'updated': '2019-05-24T10:38:03.927Z',
#   'orbit_calculated_spatial_domains': [{'equator_crossing_date_time': '2018-10-15T13:46:43.549Z',
#     'equator_crossing_longitude': '26.084411156968176',
#     'orbit_number': '460'}],
#   'dataset_id': 'ATLAS/ICESat-2 L3A Land Ice Height V001',
#   'data_center': 'NSIDC_ECS',
#   'title': 'SC:ATL06.001:161078136',
#   'coordinate_system': 'ORBIT',
#   'time_end': '2018-10-15T15:07:58.000Z',
#   'id': 'G1614520253-NSIDC_ECS',
#   'original_format': 'ISO-SMAP',
#   'granule_size': '54.5142641068',
#   'browse_flag': True,
#   'polygons': [['-78.9700441560884 17.153217861648592 -59.9822418024356 9.583386912536573 -49.754040579267226 7.885333294977224 -49.736545287138846 8.385908233605893 -59.95965119104487 10.229119211425644 -78.91110966208177 18.813791239176496 -78.9700441560884 17.153217861648592']],
#   'collection_concept_id': 'C1511847675-NSIDC_ECS',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'type': 'application/x-hdfeos',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2018.10.15/ATL06_20181015150017_02590112_001_01.h5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.default.default1.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.default.default2.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt1l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt1l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt1l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt1l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt1l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt1r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt1r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt1r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt1r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt1r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt2l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt2l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt2l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt2l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt2l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt2r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt2r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt2r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt2r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt2r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt3l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt3l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt3l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt3l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt3l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt3r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt3r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt3r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt3r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.23/ATL06_20181015150017_02590112_001_01_BRW.gt3r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'type': 'text/xml',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2018.10.15/ATL06_20181015150017_02590112_001_01.iso.xml'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/ATLAS/ATL06.001/'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'http://nsidc.org/daac/subscriptions.html'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C1511847675-NSIDC_ECS&m=-87.87967837686685!9.890967019347585!1!1!0!0%2C2&tl=1542476530!4!!&q=atl06&ok=atl06'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://openaltimetry.org/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'}]},
#  {'producer_granule_id': 'ATL06_20181019020413_03120110_001_01.h5',
#   'time_start': '2018-10-19T02:04:13.000Z',
#   'orbit': {'ascending_crossing': '-145.7364735425635',
#    'start_lat': '-50',
#    'start_direction': 'D',
#    'end_lat': '-79',
#    'end_direction': 'D'},
#   'updated': '2019-05-24T10:38:31.858Z',
#   'orbit_calculated_spatial_domains': [{'equator_crossing_date_time': '2018-10-19T01:04:05.093Z',
#     'equator_crossing_longitude': '-145.7364735425635',
#     'orbit_number': '513'}],
#   'dataset_id': 'ATLAS/ICESat-2 L3A Land Ice Height V001',
#   'data_center': 'NSIDC_ECS',
#   'title': 'SC:ATL06.001:161156556',
#   'coordinate_system': 'ORBIT',
#   'time_end': '2018-10-19T02:11:54.000Z',
#   'id': 'G1614833926-NSIDC_ECS',
#   'original_format': 'ISO-SMAP',
#   'granule_size': '11.6371736526',
#   'browse_flag': True,
#   'polygons': [['-49.55703011011742 17.132183490740474 -68.60526219080216 13.3124520499445 -78.77553376089676 8.019052693908355 -78.7176025327635 6.385807326317643 -68.57429261171143 12.429114520515743 -49.53960546405735 16.633624011460793 -49.55703011011742 17.132183490740474']],
#   'collection_concept_id': 'C1511847675-NSIDC_ECS',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'type': 'application/x-hdfeos',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2018.10.19/ATL06_20181019020413_03120110_001_01.h5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.default.default1.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.default.default2.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt1l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt1l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt1l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt1l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt1l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt1r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt1r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt1r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt1r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt1r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt2l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt2l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt2l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt2l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt2l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt2r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt2r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt2r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt2r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt2r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt3l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt3l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt3l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt3l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt3l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt3r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt3r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt3r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt3r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181019020413_03120110_001_01_BRW.gt3r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'type': 'text/xml',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2018.10.19/ATL06_20181019020413_03120110_001_01.iso.xml'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/ATLAS/ATL06.001/'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'http://nsidc.org/daac/subscriptions.html'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C1511847675-NSIDC_ECS&m=-87.87967837686685!9.890967019347585!1!1!0!0%2C2&tl=1542476530!4!!&q=atl06&ok=atl06'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://openaltimetry.org/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'}]},
#  {'producer_granule_id': 'ATL06_20181019145156_03200112_001_01.h5',
#   'time_start': '2018-10-19T14:51:56.000Z',
#   'orbit': {'ascending_crossing': '25.305794816923253',
#    'start_lat': '-79',
#    'start_direction': 'A',
#    'end_lat': '-50',
#    'end_direction': 'A'},
#   'updated': '2019-05-24T10:38:06.957Z',
#   'orbit_calculated_spatial_domains': [{'equator_crossing_date_time': '2018-10-19T13:38:24.459Z',
#     'equator_crossing_longitude': '25.305794816923253',
#     'orbit_number': '521'}],
#   'dataset_id': 'ATLAS/ICESat-2 L3A Land Ice Height V001',
#   'data_center': 'NSIDC_ECS',
#   'title': 'SC:ATL06.001:161052344',
#   'coordinate_system': 'ORBIT',
#   'time_end': '2018-10-19T14:59:37.000Z',
#   'id': 'G1614460194-NSIDC_ECS',
#   'original_format': 'ISO-SMAP',
#   'granule_size': '13.8977565765',
#   'browse_flag': True,
#   'polygons': [['-79.09548308529455 16.495894752916147 -60.10923917839485 8.829669123167816 -49.88114306762346 7.125058865816431 -49.863601782666606 7.626945893896596 -60.0865615808214 9.477875649068274 -79.03588263401842 18.174580696884533 -79.09548308529455 16.495894752916147']],
#   'collection_concept_id': 'C1511847675-NSIDC_ECS',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'type': 'application/x-hdfeos',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2018.10.19/ATL06_20181019145156_03200112_001_01.h5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.default.default1.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.default.default2.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt1l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt1l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt1l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt1l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt1l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt1r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt1r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt1r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt1r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt1r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt2l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt2l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt2l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt2l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt2l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt2r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt2r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt2r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt2r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt2r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt3l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt3l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt3l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt3l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt3l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt3r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt3r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt3r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt3r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.22/ATL06_20181019145156_03200112_001_01_BRW.gt3r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'type': 'text/xml',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2018.10.19/ATL06_20181019145156_03200112_001_01.iso.xml'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/ATLAS/ATL06.001/'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'http://nsidc.org/daac/subscriptions.html'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C1511847675-NSIDC_ECS&m=-87.87967837686685!9.890967019347585!1!1!0!0%2C2&tl=1542476530!4!!&q=atl06&ok=atl06'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://openaltimetry.org/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'}]},
#  {'producer_granule_id': 'ATL06_20181023015554_03730110_001_01.h5',
#   'time_start': '2018-10-23T01:55:54.000Z',
#   'orbit': {'ascending_crossing': '-146.5151165509519',
#    'start_lat': '-50',
#    'start_direction': 'D',
#    'end_lat': '-79',
#    'end_direction': 'D'},
#   'updated': '2019-05-24T10:38:23.337Z',
#   'orbit_calculated_spatial_domains': [{'equator_crossing_date_time': '2018-10-23T00:55:47.423Z',
#     'equator_crossing_longitude': '-146.5151165509519',
#     'orbit_number': '574'}],
#   'dataset_id': 'ATLAS/ICESat-2 L3A Land Ice Height V001',
#   'data_center': 'NSIDC_ECS',
#   'title': 'SC:ATL06.001:161147564',
#   'coordinate_system': 'ORBIT',
#   'time_end': '2018-10-23T02:03:35.000Z',
#   'id': 'G1614768094-NSIDC_ECS',
#   'original_format': 'ISO-SMAP',
#   'granule_size': '30.7274990082',
#   'browse_flag': True,
#   'polygons': [['-49.49347793194127 16.362653044979748 -68.54187770921969 12.553362364847867 -78.71276841559671 7.298235275173506 -78.65515355427965 5.673617636190326 -68.51099518278473 11.67248506039477 -49.476075909786324 15.864739017418772 -49.49347793194127 16.362653044979748']],
#   'collection_concept_id': 'C1511847675-NSIDC_ECS',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'type': 'application/x-hdfeos',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2018.10.23/ATL06_20181023015554_03730110_001_01.h5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181023015554_03730110_001_01_BRW.default.default1.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181023015554_03730110_001_01_BRW.default.default2.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181023015554_03730110_001_01_BRW.gt1l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181023015554_03730110_001_01_BRW.gt1l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181023015554_03730110_001_01_BRW.gt1l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181023015554_03730110_001_01_BRW.gt1l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181023015554_03730110_001_01_BRW.gt1l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181023015554_03730110_001_01_BRW.gt1r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181023015554_03730110_001_01_BRW.gt1r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181023015554_03730110_001_01_BRW.gt1r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181023015554_03730110_001_01_BRW.gt1r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
# ...
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181027014737_04340110_001_01_BRW.gt2r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181027014737_04340110_001_01_BRW.gt2r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181027014737_04340110_001_01_BRW.gt2r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181027014737_04340110_001_01_BRW.gt2r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181027014737_04340110_001_01_BRW.gt2r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181027014737_04340110_001_01_BRW.gt3l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181027014737_04340110_001_01_BRW.gt3l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181027014737_04340110_001_01_BRW.gt3l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181027014737_04340110_001_01_BRW.gt3l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181027014737_04340110_001_01_BRW.gt3l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181027014737_04340110_001_01_BRW.gt3r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181027014737_04340110_001_01_BRW.gt3r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181027014737_04340110_001_01_BRW.gt3r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181027014737_04340110_001_01_BRW.gt3r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181027014737_04340110_001_01_BRW.gt3r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'type': 'text/xml',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2018.10.27/ATL06_20181027014737_04340110_001_01.iso.xml'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/ATLAS/ATL06.001/'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'http://nsidc.org/daac/subscriptions.html'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C1511847675-NSIDC_ECS&m=-87.87967837686685!9.890967019347585!1!1!0!0%2C2&tl=1542476530!4!!&q=atl06&ok=atl06'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://openaltimetry.org/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'}]},
#  {'producer_granule_id': 'ATL06_20181031013919_04950110_001_01.h5',
#   'time_start': '2018-10-31T01:39:19.000Z',
#   'orbit': {'ascending_crossing': '-148.0724866638118',
#    'start_lat': '-50',
#    'start_direction': 'D',
#    'end_lat': '-79',
#    'end_direction': 'D'},
#   'updated': '2019-05-24T10:51:49.574Z',
#   'orbit_calculated_spatial_domains': [{'equator_crossing_date_time': '2018-10-31T00:39:12.548Z',
#     'equator_crossing_longitude': '-148.0724866638118',
#     'orbit_number': '696'}],
#   'dataset_id': 'ATLAS/ICESat-2 L3A Land Ice Height V001',
#   'data_center': 'NSIDC_ECS',
#   'title': 'SC:ATL06.001:161156621',
#   'coordinate_system': 'ORBIT',
#   'time_end': '2018-10-31T01:47:00.000Z',
#   'id': 'G1614835855-NSIDC_ECS',
#   'original_format': 'ISO-SMAP',
#   'granule_size': '51.0390272141',
#   'browse_flag': True,
#   'polygons': [['-49.49347793194127 14.805282932119836 -68.54187770921969 10.995992251987953 -78.71276841559671 5.74086516231359 -78.65515355427965 4.116247523330408 -68.51099518278473 10.11511494753486 -49.476075909786324 14.307368904558857 -49.49347793194127 14.805282932119836']],
#   'collection_concept_id': 'C1511847675-NSIDC_ECS',
#   'online_access_flag': True,
#   'links': [{'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'type': 'application/x-hdfeos',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2018.10.31/ATL06_20181031013919_04950110_001_01.h5'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.default.default1.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.default.default2.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt1l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt1l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt1l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt1l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt1l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt1r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt1r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt1r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt1r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt1r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt2l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt2l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt2l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt2l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt2l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt2r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt2r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt2r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt2r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt2r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt3l.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt3l.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt3l.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt3l.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt3l.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt3r.atl06_quality_summary.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt3r.h_li.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt3r.h_li_sigma.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt3r.n_fit_photons.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/browse#',
#     'type': 'image/jpeg',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP0/BRWS/Browse.001/2019.05.24/ATL06_20181031013919_04950110_001_01_BRW.gt3r.signal_selection_source.jpg'},
#    {'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'type': 'text/xml',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/DP7/ATLAS/ATL06.001/2018.10.31/ATL06_20181031013919_04950110_001_01.iso.xml'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://n5eil01u.ecs.nsidc.org/ATLAS/ATL06.001/'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'http://nsidc.org/daac/subscriptions.html'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://search.earthdata.nasa.gov/search/granules?p=C1511847675-NSIDC_ECS&m=-87.87967837686685!9.890967019347585!1!1!0!0%2C2&tl=1542476530!4!!&q=atl06&ok=atl06'},
#    {'inherited': True,
#     'length': '0.0KB',
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/data#',
#     'hreflang': 'en-US',
#     'href': 'https://openaltimetry.org/'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/metadata#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'},
#    {'inherited': True,
#     'rel': 'http://esipfed.org/ns/fedsearch/1.1/documentation#',
#     'hreflang': 'en-US',
#     'href': 'https://doi.org/10.5067/ATLAS/ATL06.001'}]}]
